# %%
# %pip install pandas
# %pip install matplotlib
# %pip install scipy
# %pip install scikit-learn
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df=pd.read_csv('House dataset csv.csv')
df
# Out:
#                Id   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520  221900         3       1.00         1180      5650     1.0
# 1      6414100192  538000         3       2.25         2570      7242     2.0
# 2      5631500400  180000         2       1.00          770     10000     1.0
# 3      2487200875  604000         4       3.00         1960      5000     1.0
# 4      1954400510  510000         3       2.00         1680      8080     1.0
# ...           ...     ...       ...        ...          ...       ...     ...
# 21608   263000018  360000         3       2.50         1530      1131     3.0
# 21609  6600060120  400000         4       2.50         2310      5813     2.0
# 21610  1523300141  402101         2       0.75         1020      1350     2.0
# 21611   291310100  400000         3       2.50         1600      2388     2.0
# 21612  1523300157  325000         2       0.75         1020      1076     2.0
#
# ...

# %%
print("The first 5 rows of the dataframe") 
df.head(5)
# Out:
# The first 5 rows of the dataframe
#            Id   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900         3       1.00         1180      5650     1.0
# 1  6414100192  538000         3       2.25         2570      7242     2.0
# 2  5631500400  180000         2       1.00          770     10000     1.0
# 3  2487200875  604000         4       3.00         1960      5000     1.0
# 4  1954400510  510000         3       2.00         1680      8080     1.0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
print("The last 10 rows of the dataframe\n")
df.tail(10)
# Out:
# The last 10 rows of the dataframe
#                Id    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 21603  7852140040   507250         3       2.50         2270      5536
# 21604  9834201367   429000         3       2.00         1490      1126
# 21605  3448900210   610685         4       2.50         2520      6023
# 21606  7936000429  1010000         4       3.50         3510      7200
# 21607  2997800021   475000         3       2.50         1310      1294
# 21608   263000018   360000         3       2.50         1530      1131
# 21609  6600060120   400000         4       2.50         2310      5813
# 21610  1523300141   402101         2       0.75         1020      1350
# 21611   291310100   400000         3       2.50         1600      2388
# 21612  1523300157   325000         2       0.75         1020      1076
#
#        floors  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# ...

# %%
headers = ["Id",	"price" , "bedrooms" , "bathrooms" , "sqft_living",	"sqft_lot",	"floors", "view",	"grade"	,"sqft_above","sqft_basement",	"yr_built","yr_renovated","zipcode","lat long","sqft_living15",	"sqft_lot15"]
print("headers\n", headers)
# Out:
# headers
#  ['Id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'view', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat long', 'sqft_living15', 'sqft_lot15']

# %%
df.head(10)
# Out:
#            Id    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520   221900         3       1.00         1180      5650     1.0
# 1  6414100192   538000         3       2.25         2570      7242     2.0
# 2  5631500400   180000         2       1.00          770     10000     1.0
# 3  2487200875   604000         4       3.00         1960      5000     1.0
# 4  1954400510   510000         3       2.00         1680      8080     1.0
# 5  7237550310  1230000         4       4.50         5420    101930     1.0
# 6  1321400060   257500         3       2.25         1715      6819     2.0
# 7  2008000270   291850         3       1.50         1060      9711     1.0
# 8  2414600126   229500         3       1.00         1780      7470     1.0
# 9  3793500160   323000         3       2.50         1890      6560     2.0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
df1=df.replace(0,np.NaN)
df=df1.dropna(subset=["view"], axis=0)
df.head(20)
# Out:
#              Id    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 15   9297300055   650000       4.0       3.00         2950      5000     2.0
# 21   2524049179  2000000       3.0       2.75         3050     44867     1.0
# 49    822039084  1350000       3.0       2.50         2753     65005     1.0
# 58   7922800400   951000       5.0       3.25         3250     14342     2.0
# 60   1516000055   650000       3.0       2.25         2150     21235     1.0
# 99   7338200240   437500       3.0       2.50         2320     36847     2.0
# 113  6126500060   329950       3.0       1.75         2080      5969     1.0
# 114  8961960160   480000       4.0       2.50         3230     16171     2.0
# 120  7278700070   660000       3.0       2.50         2400      6474     1.0
# 126  4058801670   445000       3.0       2.25         2100      8201     1.0
# 153  7855801670  2250000       4.0       3.25         5180     19850     2.0
# ...

# %%
print(df.columns)
# Out:
# Index(['Id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15',
#        'sqft_lot15'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                 int64
# price              int64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# view             float64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement    float64
# yr_built           int64
# yr_renovated     float64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.describe()
# Out:
#                  Id         price     bedrooms    bathrooms   sqft_living  \
# count  2.124000e+03  2.124000e+03  2122.000000  2122.000000   2124.000000
# mean   4.679674e+09  9.398594e+05     3.599906     2.530396   2833.566855
# std    2.900240e+09  6.624400e+05     0.989173     0.917100   1238.617689
# min    3.100016e+07  1.540000e+05     1.000000     0.750000    440.000000
# 25%    2.213725e+09  5.350000e+05     3.000000     1.750000   2007.500000
# 50%    4.058802e+09  7.500000e+05     4.000000     2.500000   2650.000000
# 75%    7.558400e+09  1.150000e+06     4.000000     3.000000   3452.500000
# max    9.830200e+09  7.700000e+06    10.000000     8.000000  13540.000000
#
#            sqft_lot       floors         view    condition        grade  \
# count  2.124000e+03  2124.000000  2124.000000  2124.000000  2124.000000
# mean   2.361946e+04     1.523540     2.384181     3.502354     8.501883
# std    6.896535e+04     0.548763     0.921944     0.691442     1.425657
# ...

# %%
df[['bedrooms', 'bathrooms' ]].describe()
# Out:
#           bedrooms    bathrooms
# count  2122.000000  2122.000000
# mean      3.599906     2.530396
# std       0.989173     0.917100
# min       1.000000     0.750000
# 25%       3.000000     1.750000
# 50%       4.000000     2.500000
# 75%       4.000000     3.000000
# max      10.000000     8.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2124 entries, 15 to 21598
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2124 non-null   int64
#  1   price          2124 non-null   int64
#  2   bedrooms       2122 non-null   float64
#  3   bathrooms      2122 non-null   float64
#  4   sqft_living    2124 non-null   int64
#  5   sqft_lot       2124 non-null   int64
#  6   floors         2124 non-null   float64
#  7   view           2124 non-null   float64
#  8   condition      2124 non-null   int64
#  9   grade          2124 non-null   int64
#  10  sqft_above     2124 non-null   int64
#  11  sqft_basement  1445 non-null   float64
#  12  yr_built       2124 non-null   int64
#  13  yr_renovated   213 non-null    float64
#  14  zipcode        2124 non-null   int64
#  15  lat            2124 non-null   float64
#  16  long           2124 non-null   float64
# ...

# %%
missingdata = df.isnull()
missingdata.head(5)
#"True" means the value is a missing value while "False" means the value is not a missing value.
# Out:
#        Id  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors   view  \
# 15  False  False     False      False        False     False   False  False
# 21  False  False     False      False        False     False   False  False
# 49  False  False     False      False        False     False   False  False
# 58  False  False     False      False        False     False   False  False
# 60  False  False     False      False        False     False   False  False
#
#     condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 15      False  False       False          False     False          True
# 21      False  False       False          False     False          True
# 49      False  False       False          False     False          True
# 58      False  False       False           True     False          True
# 60      False  False       False          False     False          True
#
#     zipcode    lat   long  sqft_living15  sqft_lot15
# ...

# %%
for column in missingdata.columns.values.tolist():
    print(column)
    print (missingdata[column].value_counts())
    print("")
# Out:
# Id
# Id
# False    2124
# Name: count, dtype: int64
#
# price
# price
# False    2124
# Name: count, dtype: int64
#
# bedrooms
# bedrooms
# False    2122
# True        2
# Name: count, dtype: int64
#
# bathrooms
# bathrooms
# False    2122
# True        2
# Name: count, dtype: int64
#
# sqft_living
# sqft_living
# False    2124
# Name: count, dtype: int64
#
# sqft_lot
# sqft_lot
# False    2124
# Name: count, dtype: int64
#
# floors
# floors
# False    2124
# Name: count, dtype: int64
#
# view
# view
# False    2124
# Name: count, dtype: int64
#
# condition
# condition
# False    2124
# Name: count, dtype: int64
#
# grade
# grade
# False    2124
# Name: count, dtype: int64
#
# sqft_above
# sqft_above
# False    2124
# Name: count, dtype: int64
#
# sqft_basement
# sqft_basement
# False    1445
# True      679
# Name: count, dtype: int64
#
# yr_built
# yr_built
# False    2124
# Name: count, dtype: int64
#
# yr_renovated
# yr_renovated
# True     1911
# False     213
# ...

# %%
avg_yr_renovated = df["yr_renovated"].astype("float").mean(axis=0)
print("Average of yr_renovated :", avg_yr_renovated)
# Out:
# Average of yr_renovated : 1994.6103286384975

# %%
df["yr_renovated"].replace(np.nan, avg_yr_renovated, inplace=True)

# %%
avg_floors=df['floors'].astype('float').mean(axis=0)
print("Average of floors:", avg_floors)
# Out:
# Average of floors: 1.5235404896421845

# %%
df["floors"].replace(np.nan,avg_floors, inplace=True)

# %%
avg_view=df['view'].astype('float').mean(axis=0)
print("Average of view:", avg_view)
# Out:
# Average of view: 2.384180790960452

# %%
df["view"].replace(np.nan,avg_view, inplace=True)

# %%
avg_bedrooms=df['bedrooms'].astype('float').mean(axis=0)
print("Average bedrooms:", avg_bedrooms)
df['bedrooms'].replace(np.nan, avg_bedrooms, inplace=True)
# Out:
# Average bedrooms: 3.5999057492931197

# %%
df['floors'].value_counts().idxmax()
# Out:
# 1.0

# %%
df.dropna(subset=["price"], axis=0, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#            Id    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  9297300055   650000       4.0       3.00         2950      5000     2.0
# 1  2524049179  2000000       3.0       2.75         3050     44867     1.0
# 2   822039084  1350000       3.0       2.50         2753     65005     1.0
# 3  7922800400   951000       5.0       3.25         3250     14342     2.0
# 4  1516000055   650000       3.0       2.25         2150     21235     1.0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0   3.0          3      9        1980          970.0      1979   1994.610329
# 1   4.0          3      9        2330          720.0      1968   1994.610329
# 2   2.0          5      9        2165          588.0      1953   1994.610329
# 3   4.0          4      8        3250            NaN      1968   1994.610329
# 4   3.0          4      8        1590          560.0      1959   1994.610329
#
# ...

# %%
import seaborn as sns

# %%
df.corr()
# Out:
#                      Id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# Id             1.000000 -0.045436  0.022234  -0.015263    -0.031529 -0.161626
# price         -0.045436  1.000000  0.309096   0.579170     0.712171 -0.006128
# bedrooms       0.022234  0.309096  1.000000   0.557560     0.553137 -0.010172
# bathrooms     -0.015263  0.579170  0.557560   1.000000     0.791614  0.051049
# sqft_living   -0.031529  0.712171  0.553137   0.791614     1.000000  0.076813
# sqft_lot      -0.161626 -0.006128 -0.010172   0.051049     0.076813  1.000000
# floors         0.001333  0.293625  0.170683   0.457464     0.363089  0.008810
# view           0.008640  0.303521  0.041069   0.167191     0.211449  0.060327
# condition     -0.051398  0.035642 -0.017294  -0.099000    -0.070918 -0.001169
# grade         -0.031605  0.667259  0.375908   0.679996     0.777920  0.023233
# sqft_above    -0.017131  0.645679  0.436809   0.722067     0.869094  0.133877
# ...

# %%
sns.regplot(x="sqft_living", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 8087868.078859326)

# %%
df[["sqft_living", "price"]].corr()
# Out:
#              sqft_living     price
# sqft_living     1.000000  0.712171
# price           0.712171  1.000000

# %%
sns.regplot(x="sqft_lot", y="price", data=df)
# Out:
# <Axes: xlabel='sqft_lot', ylabel='price'>

# %%
df[['sqft_lot','price']].corr()
# Out:
#           sqft_lot     price
# sqft_lot  1.000000 -0.006128
# price    -0.006128  1.000000

# %%
sns.boxplot(x="view",y="price",data=df)
# Out:
# <Axes: xlabel='view', ylabel='price'>

# %%
sns.boxplot(x="floors",y="price",data=df)
# Out:
# <Axes: xlabel='floors', ylabel='price'>

# %%
df.describe(include=['float64'])
# Out:
#           bedrooms    bathrooms       floors         view  sqft_basement  \
# count  2124.000000  2122.000000  2124.000000  2124.000000    1445.000000
# mean      3.599906     2.530396     1.523540     2.384181     970.992388
# std       0.988707     0.917100     0.548763     0.921944     503.907220
# min       1.000000     0.750000     1.000000     1.000000      60.000000
# 25%       3.000000     1.750000     1.000000     2.000000     610.000000
# 50%       4.000000     2.500000     1.500000     2.000000     920.000000
# 75%       4.000000     3.000000     2.000000     3.000000    1240.000000
# max      10.000000     8.000000     3.500000     4.000000    4820.000000
#
#        yr_renovated          lat         long
# count   2124.000000  2124.000000  2124.000000
# mean    1994.610329    47.564052  -122.251539
# std        4.236455     0.122423     0.142011
# min     1934.000000    47.177600  -122.514000
# 25%     1994.610329    47.512100  -122.369000
# ...

# %%
df['view'].value_counts()
#Value counts is a good way of understanding how many units of each characteristic/variable we have.
# Out:
# view
# 2.0    963
# 3.0    510
# 1.0    332
# 4.0    319
# Name: count, dtype: int64

# %%
df['view'].value_counts().to_frame()
# Out:
#       count
# view
# 2.0     963
# 3.0     510
# 1.0     332
# 4.0     319

# %%
view_counts = df['view'].value_counts().to_frame()
view_counts.rename(columns={'view': 'value_counts'}, inplace=True)
view_counts
# Out:
#       count
# view
# 2.0     963
# 3.0     510
# 1.0     332
# 4.0     319

# %%
view_counts.index.name = 'view housing'
view_counts
# Out:
#               count
# view housing
# 2.0             963
# 3.0             510
# 1.0             332
# 4.0             319

# %%
floors_counts = df['floors'].value_counts().to_frame()
floors_counts.rename(columns={'floors': 'value_counts'}, inplace=True)
floors_counts.index.name = 'floors'
floors_counts.head(10)
# Out:
#         count
# floors
# 1.0       996
# 2.0       834
# 1.5       197
# 3.0        64
# 2.5        31
# 3.5         2

# %%
df['view'].unique()
#Single test
# Out:
# array([3., 4., 2., 1.])

# %%
df_group_one = df[['view','floors','price']]

# %%
df_group_one = df_group_one.groupby(['view'],as_index=False).mean()
df_group_one
# Out:
#    view    floors         price
# 0   1.0  1.396084  8.125186e+05
# 1   2.0  1.518692  7.927462e+05
# 2   3.0  1.564706  9.724684e+05
# 3   4.0  1.605016  1.464363e+06

# %%
#multiple test - grouping result 
df_gptest = df[['view','floors','price']]
grouped_test1 = df_gptest.groupby(['view','floors'],as_index=False).mean()
grouped_test1
# Out:
#     view  floors         price
# 0    1.0     1.0  6.828976e+05
# 1    1.0     1.5  8.873459e+05
# 2    1.0     2.0  1.018241e+06
# 3    1.0     3.0  9.422900e+05
# 4    2.0     1.0  6.166980e+05
# 5    2.0     1.5  7.748012e+05
# 6    2.0     2.0  9.641731e+05
# 7    2.0     2.5  1.645101e+06
# 8    2.0     3.0  9.029479e+05
# 9    2.0     3.5  7.675000e+05
# 10   3.0     1.0  7.766509e+05
# 11   3.0     1.5  8.701400e+05
# 12   3.0     2.0  1.141282e+06
# 13   3.0     2.5  2.205625e+06
# 14   3.0     3.0  1.074708e+06
# 15   4.0     1.0  1.218262e+06
# 16   4.0     1.5  1.291586e+06
# 17   4.0     2.0  1.697258e+06
# 18   4.0     2.5  2.092833e+06
# 19   4.0     3.0  1.594412e+06

# %%
grouped_pivot = grouped_test1.pivot(index='view',columns='floors')
grouped_pivot
# Out:
#                price                                                          \
# floors           1.0           1.5           2.0           2.5           3.0
# view
# 1.0     6.828976e+05  8.873459e+05  1.018241e+06           NaN  9.422900e+05
# 2.0     6.166980e+05  7.748012e+05  9.641731e+05  1.645101e+06  9.029479e+05
# 3.0     7.766509e+05  8.701400e+05  1.141282e+06  2.205625e+06  1.074708e+06
# 4.0     1.218262e+06  1.291586e+06  1.697258e+06  2.092833e+06  1.594412e+06
#
#
# floors       3.5
# view
# 1.0          NaN
# 2.0     767500.0
# 3.0          NaN
# 4.0          NaN

# %%
df_gptest2 = df[['view','price']]
grouped_test_bodystyle = df_gptest2.groupby(['view'],as_index= False).mean()
grouped_test_bodystyle
# Out:
#    view         price
# 0   1.0  8.125186e+05
# 1   2.0  7.927462e+05
# 2   3.0  9.724684e+05
# 3   4.0  1.464363e+06

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.pcolor(grouped_pivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(df['view'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.3035210049184713  with a P-value of P = 1.6595170151019237e-46

# %%
pearson_coef, p_value = stats.pearsonr(df['yr_built'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.12086462037731355  with a P-value of P =  2.3037790101642855e-08

# %%
pearson_coef, p_value = stats.pearsonr(df['floors'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.2936251823537006  with a P-value of P =  1.6738453376050683e-43

# %%
pearson_coef, p_value = stats.pearsonr(df['grade'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.6672591435607758  with a P-value of P =  8.201036455906906e-274

# %%
pearson_coef, p_value = stats.pearsonr(df['sqft_living'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.7121714041140147  with a P-value of P =  0.0

# %%
pearson_coef, p_value = stats.pearsonr(df['sqft_lot'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.006128301955931562  with a P-value of P =  0.7777359716352483

# %%
pearson_coef, p_value = stats.pearsonr(df['sqft_above'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.6456790584483459  with a P-value of P =  7.593427442920236e-251

# %%
pearson_coef, p_value = stats.pearsonr(df['condition'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.035641638079799934  with a P-value of P =  0.1005555078545148

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
X = df[['view']]
Y = df['price']
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([1074161.8793355 , 1292249.42039712,  856074.33827388,
#        1292249.42039712, 1074161.8793355 ])

# %%
lm.intercept_
# Out:
# 419899.25615063275

# %%
lm.coef_
# Out:
# array([218087.54106162])

# %%
lm1 = LinearRegression()
lm1
# Out:
# LinearRegression()

# %%
Yhat=-796362.34 + 16662.86*X
Price=-796362.34 + 16662.86*df['view']

# %%
Z = df[['view', 'floors', 'sqft_living', 'sqft_lot']]
lm.fit(Z,df['price'])
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# -400496.70914266456

# %%
lm.coef_
# Out:
# array([ 1.16513241e+05,  4.00385504e+04,  3.58889479e+02, -6.50744039e-01])

# %%
lm2=LinearRegression()
lm2.fit(df[['bedrooms' ,'floors']],df['price'])
# Out:
# LinearRegression()

# %%
lm2.coef_
# Out:
# array([178724.39504171, 299488.5149825 ])

# %%
import seaborn as sns
# %matplotlib inline

# %%
#regression plot
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="sqft_living", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 8087959.95291633)

# %%
plt.figure(figsize=(width, height))
sns.regplot(x="sqft_lot", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 8077300.0)

# %%
#residiual plot
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(x=df['grade'], y=df['price'])
plt.show()

# %%
Y_hat = lm.predict(Z)

# %%
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price')
plt.ylabel('Proportion sqft of house')

plt.show()
plt.close()

# %%
#Polynomial regression
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of house')

    plt.show()
    plt.close()

# %%
x = df['sqft_living']
y = df['price']

# %%
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#             3           2
# -4.424e-06 x + 0.08923 x - 54.21 x + 4.114e+05

# %%
PlotPolly(p, x, y, 'sqft_living')

# %%
np.polyfit(x, y, 3)
# Out:
# array([-4.42420479e-06,  8.92266420e-02, -5.42065258e+01,  4.11428437e+05])

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr=PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
Z_pr=pr.fit_transform(Z)

# %%
Z.shape
# Out:
# (2124, 4)

# %%
Z_pr.shape
# Out:
# (2124, 15)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
Z = Z.astype(float)
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
#pipeline model prediction
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([1015077.1268906 , 1147675.41123127,  698535.53660278,
#        1421530.44999081])

# %%
Input=[('scale',StandardScaler()),('model',LinearRegression())]

pipe=Pipeline(Input)

pipe.fit(Z,y)

ypipe=pipe.predict(Z)
ypipe[0:10]
# Out:
# array([1084590.35506217, 1171010.78051823,  818289.44073447,
#        1302691.18841525,  746875.39232238,  721252.497531  ,
#         615174.14673848, 1177809.94740892,  729690.1541534 ,
#         620899.4756148 ])

# %%
#highway_mpg_fit
lm.fit(X, Y)
# Find the R^2
print('The R-square is: ', lm.score(X, Y))
# Out:
# The R-square is:  0.09212500042671867

# %%
Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [1074161.8793355  1292249.42039712  856074.33827388 1292249.42039712]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  398212308210.8165

# %%
lm.fit(Z, df['price'])
# Find the R^2
print('The R-square is: ', lm.score(Z, df['price']))
# Out:
# The R-square is:  0.5372706832695322

# %%
Y_predict_multifit = lm.predict(Z)

# %%
print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(df['price'], Y_predict_multifit))
# Out:
# The mean square error of price and predicted value using multifit is:  202962422556.69714

# %%
from sklearn.metrics import r2_score

# %%
r_squared = r2_score(y, p(x))
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.5267759030701319

# %%
mean_squared_error(df['price'], p(x))
# Out:
# 207565645081.08945

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
new_input=np.arange(1, 100, 1).reshape(-1, 1)

# %%
lm.fit(X, Y)
lm
# Out:
# LinearRegression()

# %%
yhat=lm.predict(new_input)
yhat[0:5]
# Out:
# array([ 637986.79721226,  856074.33827388, 1074161.8793355 ,
#        1292249.42039712, 1510336.96145874])

# %%
plt.plot(new_input, yhat)
plt.show()

# %%
df.head()
# Out:
#            Id    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  9297300055   650000       4.0       3.00         2950      5000     2.0
# 1  2524049179  2000000       3.0       2.75         3050     44867     1.0
# 2   822039084  1350000       3.0       2.50         2753     65005     1.0
# 3  7922800400   951000       5.0       3.25         3250     14342     2.0
# 4  1516000055   650000       3.0       2.25         2150     21235     1.0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0   3.0          3      9        1980          970.0      1979   1994.610329
# 1   4.0          3      9        2330          720.0      1968   1994.610329
# 2   2.0          5      9        2165          588.0      1953   1994.610329
# 3   4.0          4      8        3250            NaN      1968   1994.610329
# 4   3.0          4      8        1590          560.0      1959   1994.610329
#
# ...

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
#Libraries for ploting

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    ax1 = sns.kdeplot(RedFunction, color="r", label=RedName)
    ax2 = sns.kdeplot(BlueFunction, color="b", label=BlueName, ax=ax1)

    plt.title(Title)
    plt.xlabel('Price')
    plt.ylabel('Square fit living')
    plt.show()
    plt.close()

# %%
def PollyPlot(xtrain, xtest, y_train, y_test, lr,poly_transform):
    width = 12
    height = 10
    plt.figure(figsize=(width, height))
    
    
    #training data 
    #testing data 
    # lr:  linear regression object 
    #poly_transform:  polynomial transformation object 
 
    xmax=max([xtrain.values.max(), xtest.values.max()])

    xmin=min([xtrain.values.min(), xtest.values.min()])

    x=np.arange(xmin, xmax, 0.1)


    plt.plot(xtrain, y_train, 'ro', label='Training Data')
    plt.plot(xtest, y_test, 'go', label='Test Data')
    plt.plot(x, lr.predict(poly_transform.fit_transform(x.reshape(-1, 1))), label='Predicted Function')
    plt.ylim([-10000, 60000])
    plt.ylabel('Price')
    plt.legend()

# %%
y_data = df['price']

# %%
x_data=df.drop('price',axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.10, random_state=1)

print("number of test samples :", x_test.shape[0])
print("number of training samples:",x_train.shape[0])
# Out:
# number of test samples : 213
# number of training samples: 1911

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x_data, y_data, test_size=0.4, random_state=0) 
print("number of test samples :", x_test1.shape[0])
print("number of training samples:",x_train1.shape[0])
# Out:
# number of test samples : 850
# number of training samples: 1274

# %%
from sklearn.linear_model import LinearRegression

# %%
lre=LinearRegression()

# %%
lre.fit(x_train[['sqft_living']], y_train)
# Out:
# LinearRegression()

# %%
lre.score(x_test[['sqft_living']], y_test)
# Out:
# 0.48197852264915

# %%
lre.fit(x_train[['sqft_living']], y_train)
# Out:
# LinearRegression()

# %%
lre.score(x_train[['sqft_living']], y_train)
# Out:
# 0.5092615476174305

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x_data, y_data, test_size=0.4, random_state=0)
lre.fit(x_train1[['sqft_living']],y_train1)
lre.score(x_test1[['sqft_living']],y_test1)
# r^2 using 40% of dataset
# Out:
# 0.47832952327137435

# %%
from sklearn.model_selection import cross_val_score
# cross validation check

# %%
Rcross = cross_val_score(lre, x_data[['sqft_living']], y_data, cv=4)

# %%
Rcross
# Out:
# array([0.50619961, 0.58622227, 0.45875196, 0.42530601])

# %%
print("The mean of the folds are", Rcross.mean(), "and the standard deviation is" , Rcross.std())
# mean and standard deviation
# Out:
# The mean of the folds are 0.49411996303658506 and the standard deviation is 0.060446276125012986

# %%
-1 * cross_val_score(lre,x_data[['sqft_living']], y_data,cv=4,scoring='neg_mean_squared_error')
# Out:
# array([2.55248977e+11, 2.05098427e+11, 1.90392418e+11, 2.22943321e+11])

# %%
Rc=cross_val_score(lre,x_data[['sqft_living']], y_data,cv=2)
Rc.mean()
# Out:
# 0.4800877843519863

# %%
#Model selection of the given dataset
lr = LinearRegression()
lr.fit(x_train[['sqft_living', 'sqft_lot', 'sqft_above', 'yr_built']], y_train)
# Out:
# LinearRegression()

# %%
yhat_train = lr.predict(x_train[['sqft_living', 'sqft_lot', 'sqft_above', 'yr_built']])
yhat_train[0:5]
# Out:
# array([1165464.48566621, 1078293.67270347,  996728.75070175,
#         763782.46469245,  688246.76692569])

# %%
yhat_test = lr.predict(x_test[['sqft_living', 'sqft_lot', 'sqft_above', 'yr_built']])
yhat_test[0:5]
# Out:
# array([ 611306.32606137,  251153.26512453, 1361273.44213608,
#        1191531.92953717,  339637.08791444])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
Title = 'Distribution  Plot of  Predicted Value Using Training Data vs Training Data Distribution'
DistributionPlot(y_train, yhat_train, "Actual Values (Train)", "Predicted Values (Train)", Title)

# %%
Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'
DistributionPlot(y_test,yhat_test,"Actual Values (Test)","Predicted Values (Test)",Title)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.45, random_state=0)
# 55percent of data using in train_test_split model selection

# %%
x_train_pr = pr.fit_transform(x_train[['view']])
x_test_pr = pr.fit_transform(x_test[['view']])
pr
# Out:
# PolynomialFeatures()

# %%
poly = LinearRegression()
poly.fit(x_train_pr, y_train)
# Out:
# LinearRegression()

# %%
yhat = poly.predict(x_test_pr)
yhat[0:5]
# Out:
# array([1501789.04255878,  780911.27951546,  780911.27951546,
#        1007206.17696123,  780911.27951546])

# %%
print("Predicted values:", yhat[0:4])
print("True values:", y_test[0:4].values)
# Out:
# Predicted values: [1501789.04255878  780911.27951546  780911.27951546 1007206.17696123]
# True values: [1370000  855000  981000  265000]

# %%
poly.score(x_train_pr, y_train)
# Out:
# 0.13635058222575158

# %%
poly.score(x_test_pr, y_test)
# Out:
# 0.10025895751816216

# %%
pr1=PolynomialFeatures(degree=2)

# %%
x_train_pr1=pr1.fit_transform(x_train[['sqft_living', 'sqft_lot', 'sqft_above', 'yr_renovated']])

x_test_pr1=pr1.fit_transform(x_test[['sqft_living', 'sqft_lot', 'sqft_above', 'yr_renovated']])

# %%
x_train_pr1.shape #there are now 15 features
# Out:
# (1168, 15)

# %%
poly1=LinearRegression().fit(x_train_pr1,y_train)

# %%
yhat_test1=poly1.predict(x_test_pr1)

Title='Distribution  Plot of  Predicted Value Using Test Data vs Data Distribution of Test Data'

DistributionPlot(y_test, yhat_test1, "Actual Values (Test)", "Predicted Values (Test)", Title)

# %%
pr=PolynomialFeatures(degree=2)
x_train_pr=pr.fit_transform(x_train[['sqft_living', 'sqft_lot', 'sqft_above', 'yr_renovated','yr_built']])
x_test_pr=pr.fit_transform(x_test[['sqft_living', 'sqft_lot', 'sqft_above', 'yr_renovated','yr_built']])

# %%
#Ridge regression 
from sklearn.linear_model import Ridge

# %%
RigeModel=Ridge(alpha=1)

# %%
RigeModel.fit(x_train_pr, y_train)
# Out:
# Ridge(alpha=1)

# %%
yhat = RigeModel.predict(x_test_pr)

# %%
print('predicted:', yhat[0:4])
print('test set :', y_test[0:4].values)
# Out:
# predicted: [1170060.18930638 1164184.38166344  831798.33751118  364445.72527635]
# test set : [1370000  855000  981000  265000]

# %%
#We select the value of alpha that minimizes the test error. To do so, we can use a for loop. We have also created a progress bar to see how many iterations we have completed so far.
from tqdm import tqdm

Rsqu_test = []
Rsqu_train = []
dummy1 = []
Alpha = 10 * np.array(range(0,1000))
pbar = tqdm(Alpha)

for alpha in pbar:
    RigeModel = Ridge(alpha=alpha) 
    RigeModel.fit(x_train_pr, y_train)
    test_score, train_score = RigeModel.score(x_test_pr, y_test), RigeModel.score(x_train_pr, y_train)
    
    pbar.set_postfix({"Test Score": test_score, "Train Score": train_score})

    Rsqu_test.append(test_score)
    Rsqu_train.append(train_score)
# Out:
# 100%|██████████| 1000/1000 [00:04<00:00, 207.39it/s, Test Score=0.34, Train Score=0.615]

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))

plt.plot(Alpha,Rsqu_test, label='validation data  ')
plt.plot(Alpha,Rsqu_train, 'r', label='training Data ')
plt.xlabel('alpha')
plt.ylabel('R^2')
plt.legend()

# %%
RigeModel = Ridge(alpha=10) 
RigeModel.fit(x_train_pr, y_train)
RigeModel.score(x_test_pr, y_test)
# Out:
# 0.33896343176785537

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters1= [{'alpha': [0.001,0.1,1, 10, 100, 1000, 10000, 100000, 100000]}]
parameters1
#dictnorary of alpha parameters
# Out:
# [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

# %%
RR=Ridge()
RR
# Out:
# Ridge()

# %%
#Grid ridge of model
Grid1 = GridSearchCV(RR, parameters1,cv=4)

# %%
parameters2 = [{'alpha': [0.001, 0.1, 1, 10, 100, 1000, 10000, 100000, 100000]}]

Grid2 = GridSearchCV(Ridge(), parameters2, cv=4)
Grid2.fit(x_data[['sqft_living', 'sqft_lot', 'sqft_above', 'yr_renovated']], y_data)
best_alpha = Grid2.best_params_['alpha']
best_ridge_model = Ridge(alpha=best_alpha)
best_ridge_model.fit(x_data[['sqft_living', 'sqft_lot', 'sqft_above', 'yr_renovated']], y_data)
# Out:
# Ridge(alpha=100000)
